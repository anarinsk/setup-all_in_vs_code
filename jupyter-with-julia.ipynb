# %%
using InstantiateFromURL
github_project("QuantEcon/quantecon-notebooks-julia", version = "0.8.0", instantiate = true, precompile = true)
# Out:
# ed QuadGK ───────────────────────── v2.4.1
#   Installed AbstractFFTs ─────────────────── v0.5.0
#   Installed BlockBandedMatrices ──────────── v0.8.11
#   Installed ExponentialUtilities ─────────── v1.8.0
#   Installed Xorg_xcb_util_jll ────────────── v0.4.0+1
#   Installed FFMPEG ───────────────────────── v0.4.0
#   Installed Random123 ────────────────────── v1.3.1
#   Installed Xorg_libXrandr_jll ───────────── v1.5.2+4
#   Installed SparseDiffTools ──────────────── v1.13.0
#   Installed ShiftedArrays ────────────────── v1.0.0
#   Installed CEnum ────────────────────────── v0.4.1
#   Installed DataAPI ──────────────────────── v1.4.1
#   Installed SpatialIndexing ──────────────── v0.1.2
#   Installed Cairo_jll ────────────────────── v1.16.0+6
#   Installed DiffRules ────────────────────── v1.0.2
#   Installed CompilerSupportLibraries_jll ─── v0.3.4+0
#   Installed METIS_jll ────────────────────── v5.1.0+5
#   Installed LoopVectorization ────────────── v0.10.0
#   Installed NLsolve ──────────────────────── v4.5.1
#   Installed RegressionTables ─────────────── v0.5.0
#   Installed DataValues ───────────────────── v0.4.13
#   Installed LinearOperators ──────────────── v1.2.0
#   Installed ApproxFunSingularities ───────── v0.2.1
#   Installed AxisAlgorithms ───────────────── v1.0.0
#   Installed Expat_jll ────────────────────── v2.2.7+6
#   Installed CPUTime ──────────────────────── v1.0.0
#   Installed AbstractTrees ────────────────── v0.3.3
#   Installed GenericSVD ───────────────────── v0.3.0
#   Installed PrettyPrint ──────────────────── v0.2.0
#   Installed Contour ──────────────────────── v0.5.7
#   Installed LoggingExtras ────────────────── v0.4.4
#   Installed CategoricalArrays ────────────── v0.9.0
#   Installed ChainRules ───────────────────── v0.7.49
#   Installed QueryOperators ───────────────── v0.9.3
#   Installed MultivariateStats ────────────── v0.7.0
#   Installed GR_jll ───────────────────────── v0.53.0+0
#   Installed ZipFile ──────────────────────── v0.9.3
#   Installed Preconditioners ──────────────── v0.3.0
#   Installed CanonicalTraits ──────────────── v0.2.3
#   Installed ArnoldiMethod ────────────────── v0.1.0
#   Installed CompatHelper ─────────────────── v1.16.3
#   Installed NLopt ────────────────────────── v0.6.0
#   Installed libfdk_aac_jll ───────────────── v0.1.6+4
#   Installed Showoff ──────────────────────── v0.3.2
#   Installed FFTW_jll ─────────────────────── v3.3.9+7
#   Installed LAME_jll ─────────────────────── v3.100.0+3
#   Installed DiffEqOperators ──────────────── v4.12.0
#   Installed ChainRulesCore ───────────────── v0.9.27
#   Installed LeastSquaresOptim ────────────── v0.8.1
#   Installed Optim ────────────────────────── v1.2.3
#   Installed Xorg_libxkbfile_jll ──────────── v1.1.0+4
#   Installed MatrixFactorizations ─────────── v0.5.2
#   Installed GLFW_jll ─────────────────────── v3.3.2+1
#   Installed BlackBoxOptim ────────────────── v0.5.0
#   Installed SLEEFPirates ─────────────────── v0.6.8
#   Installed Xorg_libX11_jll ──────────────── v1.6.9+4
#   Installed Rmath_jll ────────────────────── v0.2.2+1
#   Installed StatsFuns ────────────────────── v0.9.6
#   Installed DataFramesMeta ───────────────── v0.6.0
#   Installed DataStructures ───────────────── v0.17.20
#   Installed LightGraphs ──────────────────── v1.3.5
#   Installed FiniteDiff ───────────────────── v2.8.0
#   Installed Functors ─────────────────────── v0.1.0
#   Installed Libffi_jll ───────────────────── v3.2.1+4
#   Installed FilePathsBase ────────────────── v0.9.8
#   Installed TranscodingStreams ───────────── v0.9.5
#   Installed LoweredCodeUtils ─────────────── v1.2.7
#   Installed PrettyTables ─────────────────── v0.11.0
#   Installed MKL_jll ──────────────────────── v2020.2.254+0
#   Installed Ipopt_jll ────────────────────── v3.13.2+1
#   Installed StatsPlots ───────────────────── v0.14.17
#   Installed Vcov ─────────────────────────── v0.4.0
#   Installed DocStringExtensions ──────────── v0.8.3
#   Installed Interpolations ───────────────── v0.13.1
#   Installed OpenSpecFun_jll ──────────────── v0.5.3+4
#   Installed Distributions ────────────────── v0.23.8
#   Installed TableOperations ──────────────── v0.3.0
#   Installed Xorg_xcb_util_keysyms_jll ────── v0.4.0+1
#   Installed OpenBLAS_jll ─────────────────── v0.3.9+5
#   Installed Xorg_xcb_util_renderutil_jll ─── v0.3.9+1
#   Installed PooledArrays ─────────────────── v1.0.0
#   Installed BandedMatrices ───────────────── v0.15.15
#   Installed Libglvnd_jll ─────────────────── v1.3.0+3
#   Installed Xorg_libXrender_jll ──────────── v0.9.10+4
#   Installed ResettableStacks ─────────────── v1.1.0
#   Installed Ratios ───────────────────────── v0.4.0
#   Installed InvertedIndices ──────────────── v1.0.0
#   Installed Setfield ─────────────────────── v0.6.0
#   Installed Roots ────────────────────────── v1.0.7
#   Installed UnPack ───────────────────────── v1.0.2
#   Installed PCRE_jll ─────────────────────── v8.42.0+4
#   Installed Glob ─────────────────────────── v1.3.0
#   Installed SimpleTraits ─────────────────── v0.9.3
#   Installed LaTeXStrings ─────────────────── v1.2.0
#   Installed Intervals ────────────────────── v1.5.0
#   Installed Measures ─────────────────────── v0.3.1
#   Installed Glib_jll ─────────────────────── v2.59.0+4
#   Installed FastGaussQuadrature ──────────── v0.4.5
#   Installed MathOptInterface ─────────────── v0.9.13
#   Installed Xorg_libXau_jll ──────────────── v1.0.9+4
#   Installed x264_jll ─────────────────────── v2020.7.14+2
#   Installed PlotUtils ────────────────────── v1.0.10
#   Installed RecipesBase ──────────────────── v1.1.1
#   Installed LabelledArrays ───────────────── v1.5.0
#   Installed XSLT_jll ─────────────────────── v1.1.33+4
#   Installed Libuuid_jll ──────────────────── v2.34.0+7
#   Installed IncompleteLU ─────────────────── v0.2.0
#   Installed Mustache ─────────────────────── v1.0.10
#   Installed JpegTurbo_jll ────────────────── v2.0.1+3
#   Installed ConsoleProgressMonitor ───────── v0.1.2
#   Installed SafeTestsets ─────────────────── v0.0.1
#   Installed XML2_jll ─────────────────────── v2.9.10+3
#   Installed Libgcrypt_jll ────────────────── v1.8.5+4
#   Installed LowRankApprox ────────────────── v0.4.3
#   Installed Revise ───────────────────────── v3.1.11
#   Installed DSP ──────────────────────────── v0.6.10
#   Installed DataValueInterfaces ──────────── v1.0.0
#   Installed Arpack ───────────────────────── v0.4.0
#   Installed Crayons ──────────────────────── v4.0.4
#   Installed Libgpg_error_jll ─────────────── v1.36.0+3
#   Installed DiffResults ──────────────────── v1.0.3
#   Installed AbstractAlgebra ──────────────── v0.11.2
#   Installed x265_jll ─────────────────────── v3.0.0+3
#   Installed SymbolicUtils ────────────────── v0.5.2
#   Installed Unitful ──────────────────────── v1.5.0
#   Installed TableTraits ──────────────────── v1.0.0
#   Installed libass_jll ───────────────────── v0.14.0+4
#   Installed Pixman_jll ───────────────────── v0.40.0+0
#   Installed FFTW ─────────────────────────── v1.3.0
#   Installed Xorg_xkeyboard_config_jll ────── v2.27.0+4
#   Installed DualNumbers ──────────────────── v0.6.3
#   Installed IterativeSolvers ─────────────── v0.8.5
#   Installed FastTransforms_jll ───────────── v0.3.3+0
#   Installed Xorg_xcb_util_image_jll ──────── v0.4.0+1
#   Installed CodecBzip2 ───────────────────── v0.7.2
#   Installed TimeZones ────────────────────── v1.5.3
#   Installed StatsModels ──────────────────── v0.6.19
#   Installed Polynomials ──────────────────── v1.2.0
#   Installed RecipesPipeline ──────────────── v0.2.1
#   Installed SortingAlgorithms ────────────── v0.3.1
#   Installed FixedEffects ─────────────────── v2.0.0
#   Installed DiffEqNoiseProcess ───────────── v5.5.1
#   Installed ApproxFunOrthogonalPolynomials ─ v0.3.9
#   Installed KernelDensity ────────────────── v0.6.2
#   Installed Wayland_jll ──────────────────── v1.17.0+4
#   Installed TerminalLoggers ──────────────── v0.1.3
#   Installed Reexport ─────────────────────── v0.2.0
#   Installed ColorSchemes ─────────────────── v3.10.2
#   Installed IterableTables ───────────────── v1.0.0
#   Installed OffsetArrays ─────────────────── v1.5.2
#   Installed NLopt_jll ────────────────────── v2.7.0+0
#   Installed ColorTypes ───────────────────── v0.10.9
#   Installed Xorg_libXi_jll ───────────────── v1.7.10+4
#   Installed OpenBLAS32_jll ───────────────── v0.3.9+4
#   Installed Inflate ──────────────────────── v0.1.2
#   Installed StaticArrays ─────────────────── v0.12.5
#   Installed Media ────────────────────────── v0.5.0
#   Installed Dierckx_jll ──────────────────── v0.0.1+0
#   Installed EllipsisNotation ─────────────── v1.0.0
#   Installed LimitedLDLFactorizations ─────── v0.3.0
#   Installed FastClosures ─────────────────── v0.3.2
#   Installed GR ───────────────────────────── v0.53.0
#   Installed URIParser ────────────────────── v0.4.1
#   Installed StatsBase ────────────────────── v0.33.2
#   Installed ArrayInterface ───────────────── v2.14.17
#   Installed Xorg_libpthread_stubs_jll ────── v0.1.0+3
#   Installed LineSearches ─────────────────── v7.1.1
#   Installed ConstructionBase ─────────────── v1.0.0
#   Installed IRTools ──────────────────────── v0.4.2
#   Installed StructTypes ──────────────────── v1.2.3
#   Installed MuladdMacro ──────────────────── v0.2.2
#   Installed Libmount_jll ─────────────────── v2.34.0+3
#   Installed BenchmarkTools ───────────────── v0.5.0
#   Installed Rmath ────────────────────────── v0.6.1
#   Installed Clustering ───────────────────── v0.14.2
#   Installed InfiniteArrays ───────────────── v0.7.3
#   Installed FreeType2_jll ────────────────── v2.10.1+5
#   Installed Gettext_jll ──────────────────── v0.20.1+7
#   Installed Xorg_libxcb_jll ──────────────── v1.13.0+3
#   Installed SparsityDetection ────────────── v0.3.3
#   Installed StochasticDiffEq ─────────────── v6.25.0
#   Installed Krylov ───────────────────────── v0.6.0
#   Installed CUDA ─────────────────────────── v2.4.1
#   Installed RDatasets ────────────────────── v0.7.3
#   Installed Ipopt ────────────────────────── v0.6.5
#   Installed FriBidi_jll ──────────────────── v1.0.5+6
#   Installed Distances ────────────────────── v0.10.2
#   Installed Scratch ──────────────────────── v1.0.3
#   Installed Mocking ──────────────────────── v0.7.1
#   Installed QuantEcon ────────────────────── v0.16.2
#   Installed LLVM ─────────────────────────── v3.6.0
#   Installed RData ────────────────────────── v0.7.3
#   Installed Widgets ──────────────────────── v0.6.2
#   Installed IntervalSets ─────────────────── v0.5.2
#   Installed DiffEqBase ───────────────────── v6.44.3
#   Installed TreeViews ────────────────────── v0.3.0
#   Installed Hwloc_jll ────────────────────── v2.4.0+0
#   Installed PoissonRandom ────────────────── v0.4.0
#   Installed Query ────────────────────────── v1.0.0
#   Installed NaNMath ──────────────────────── v0.3.5
#   Installed IntelOpenMP_jll ──────────────── v2018.0.3+2
#   Installed Latexify ─────────────────────── v0.14.7
#   Installed Cassette ─────────────────────── v0.3.4
#   Installed Calculus ─────────────────────── v0.5.1
#   Installed Xorg_xcb_util_wm_jll ─────────── v0.4.1+1
#   Installed Arpack_jll ───────────────────── v3.5.0+3
#   Installed Parameters ───────────────────── v0.12.2
#   Installed GMP_jll ──────────────────────── v6.1.2+6
#   Installed Bzip2_jll ────────────────────── v1.0.6+5
#   Installed ApproxFunFourier ─────────────── v0.2.7
#   Installed IterTools ────────────────────── v1.3.0
#   Installed LazyBandedMatrices ───────────── v0.2.12
#   Installed ProgressLogging ──────────────── v0.1.4
#   Installed DiffEqJump ───────────────────── v6.10.0
#   Installed PlotThemes ───────────────────── v2.0.0
#   Installed RandomNumbers ────────────────── v1.4.0
#    Building FFTW ───────────→ `/opt/julia/packages/FFTW/ayqyZ/deps/build.log`
#    Building TimeZones ──────→ `/opt/julia/packages/TimeZones/K98G0/deps/build.log`
#    Building FastTransforms ─→ `/opt/julia/packages/FastTransforms/LB2TC/deps/build.log`
#    Building PyCall ─────────→ `/opt/julia/packages/PyCall/tqyST/deps/build.log`
#    Building Random123 ──────→ `/opt/julia/packages/Random123/cb3eU/deps/build.log`
#    Building Preconditioners → `/opt/julia/packages/Preconditioners/uMaQw/deps/build.log`
#    Building GR ─────────────→ `/opt/julia/packages/GR/RlE5Y/deps/build.log`
#    Building Ipopt ──────────→ `/opt/julia/packages/Ipopt/P1XLY/deps/build.log`
# Precompiling project...
# ┌ Info: Precompiling ForwardDiff [f6369f11-7733-5829-9624-2563aa707210]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Preconditioners [af69fa37-3177-5a40-98ee-561f696e4fcd]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Arpack [7d9fca2a-8960-54d3-9f78-7d1dccf2cb97]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling RegressionTables [d519eb52-b820-54da-95a6-98e1306fdade]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling StochasticDiffEq [789caeaf-c7a9-5a7d-9973-96adeb23e2a0]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling IncompleteLU [40713840-3770-5561-ab4c-a76e7d0d7895]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling SparsityDetection [684fba80-ace3-11e9-3d08-3bc7ed6f96df]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling LazyArrays [5078a376-72f3-5289-bfd5-ec5146d43c02]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling ModelingToolkit [961ee093-0014-501f-94e3-6117800e7a78]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Zygote [e88e6eb3-aa80-5325-afca-941959d7151f]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Expectations [2fe49d83-0758-5602-8f54-1f90ad0d522b]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling LeastSquaresOptim [0fc2ff8b-aaa3-5acd-a817-1944a5e08891]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling GR [28b8d3ca-fb5f-59d9-8090-bfdbd6d07a71]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Krylov [ba0b0d4f-ebba-5204-a429-3ac8c609bfb7]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling KrylovKit [0b1a1467-8014-51b9-945f-bf0ae24f4b77]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling VegaLite [112f6efa-9a02-5b7d-90c0-432ed331239a]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling KernelDensity [5ab0869b-81aa-558d-bb23-cbf5423bbe9b]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Polynomials [f27b6e38-b328-58d1-80ce-0feddd5e7a45]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling ApproxFun [28f2ccd6-bb30-5033-b560-165f7b14dc2f]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Revise [295af30f-e4ad-537b-8983-00126c2a3abe]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling BenchmarkTools [6e4b80f9-dd63-53aa-95a3-0cdb28fa8baf]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Expokit [a1e7a1ef-7a5d-5822-a38c-be74e1bb89f4]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling DataFramesMeta [1313f7d8-7da2-5740-9ea0-a2ca25f37964]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Dierckx [39dd38d3-220a-591b-8e3c-4c3a8c710a94]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Flux [587475ba-b771-5e3f-ad9e-33799f191a9c]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling BlackBoxOptim [a134a8b2-14d6-55f6-9291-3336d3ab0209]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling UnicodePlots [b8865327-cd53-5732-bb35-84acbb429228]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling LinearMaps [7a12625a-238d-50fd-b39a-03d52299707e]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling JuMP [4076af6c-e467-56ae-b986-b466b2749572]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Query [1a8c2f83-1ff3-5112-b086-8aa67b057ba1]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling DiffEqOperators [9fdde737-9c7f-55bf-ade8-46b3f136cc48]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Ipopt [b6b21f68-93f8-5de0-b562-5493be1d77c9]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling NLopt [76087f3c-5699-56af-9a33-bf431cd00edd]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling PkgTemplates [14b8a8f1-9102-5b29-a752-f990bacb7fe1]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling RDatasets [ce6b1742-4840-55fa-b093-852dadbb1d8b]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling QuantEcon [fcd29c91-0bd7-5a09-975d-7ac3f643a60c]
# └ @ Base loading.jl:1278

# %%
using Pkg
Pkg.add("PyPlot")
Pkg.add("UnicodePlots")
# Out:
#    Updating registry at `/opt/julia/registries/General`
#   Resolving package versions...
# No Changes to `~/github-anari/setup-all_in_vs_code/Project.toml`
# No Changes to `~/github-anari/setup-all_in_vs_code/Manifest.toml`
#   Resolving package versions...
# No Changes to `~/github-anari/setup-all_in_vs_code/Project.toml`
# No Changes to `~/github-anari/setup-all_in_vs_code/Manifest.toml`

# %%
## Plot by using pyplot 
n = 100
x, y = range(0, 1, length = n), randn(n, 3)

using Plots; 
pyplot(size = (600, 300))

plot(
    x, y,
    line = (0.5, [4 1 0], [:path :scatter :histogram]),
    normalize = true,
    bins = 30,
    marker = (10, 0.5, [:none :+ :none]),
    markerstrokewidth = 0,
    color = [:steelblue :orangered :green],
    fill = 0.5,
    orientation = [:v :v :h],
    title = "My title",
    )

# %%
using Plots
pyplot(size = (600, 300))

group = rand(map((i->begin
                    "group $(i)"
                end), 1:4), 100)
plot(rand(100), layout = @layout([a b; c]), group = group, linetype = [:bar :scatter :steppre], linecolor = :match, size=(700, 500))
