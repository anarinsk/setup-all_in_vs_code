# %%
using InstantiateFromURL
github_project("QuantEcon/quantecon-notebooks-julia", version = "0.8.0", instantiate = true, precompile = true)
# Out:
# Activated /home/jovyan/github-anari/setup-all*in*vs_code/Project.toml
# Info Project name is quantecon-notebooks-julia, version is 0.8.0
# Precompiling project...
# ┌ Info: Precompiling ForwardDiff [f6369f11-7733-5829-9624-2563aa707210]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Preconditioners [af69fa37-3177-5a40-98ee-561f696e4fcd]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Arpack [7d9fca2a-8960-54d3-9f78-7d1dccf2cb97]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling RegressionTables [d519eb52-b820-54da-95a6-98e1306fdade]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling StochasticDiffEq [789caeaf-c7a9-5a7d-9973-96adeb23e2a0]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling IncompleteLU [40713840-3770-5561-ab4c-a76e7d0d7895]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling SparsityDetection [684fba80-ace3-11e9-3d08-3bc7ed6f96df]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling LazyArrays [5078a376-72f3-5289-bfd5-ec5146d43c02]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling ModelingToolkit [961ee093-0014-501f-94e3-6117800e7a78]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Zygote [e88e6eb3-aa80-5325-afca-941959d7151f]
# └ @ Base loading.jl:1278
# WARNING: could not import Compiler.just_construct_ssa into Wrap
# ┌ Info: Precompiling Expectations [2fe49d83-0758-5602-8f54-1f90ad0d522b]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling LeastSquaresOptim [0fc2ff8b-aaa3-5acd-a817-1944a5e08891]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling GR [28b8d3ca-fb5f-59d9-8090-bfdbd6d07a71]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Krylov [ba0b0d4f-ebba-5204-a429-3ac8c609bfb7]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling KrylovKit [0b1a1467-8014-51b9-945f-bf0ae24f4b77]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling VegaLite [112f6efa-9a02-5b7d-90c0-432ed331239a]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling KernelDensity [5ab0869b-81aa-558d-bb23-cbf5423bbe9b]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Polynomials [f27b6e38-b328-58d1-80ce-0feddd5e7a45]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling ApproxFun [28f2ccd6-bb30-5033-b560-165f7b14dc2f]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Revise [295af30f-e4ad-537b-8983-00126c2a3abe]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling BenchmarkTools [6e4b80f9-dd63-53aa-95a3-0cdb28fa8baf]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Expokit [a1e7a1ef-7a5d-5822-a38c-be74e1bb89f4]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling DataFramesMeta [1313f7d8-7da2-5740-9ea0-a2ca25f37964]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Dierckx [39dd38d3-220a-591b-8e3c-4c3a8c710a94]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Flux [587475ba-b771-5e3f-ad9e-33799f191a9c]
# └ @ Base loading.jl:1278
# ERROR: LoadError: LoadError: LoadError: UndefVarError: AddrSpacePtr not defined
# Stacktrace:
#  [1] getproperty(::Module, ::Symbol) at ./Base.jl:26
#  [2] top-level scope at /opt/julia/packages/CUDAnative/e0IdN/src/device/cuda/wmma.jl:52
#  [3] include(::Function, ::Module, ::String) at ./Base.jl:380
#  [4] include at ./Base.jl:368 [inlined]
#  [5] include(::String) at /opt/julia/packages/CUDAnative/e0IdN/src/CUDAnative.jl:1
#  [6] top-level scope at /opt/julia/packages/CUDAnative/e0IdN/src/device/cuda.jl:15
#  [7] include(::Function, ::Module, ::String) at ./Base.jl:380
#  [8] include at ./Base.jl:368 [inlined]
#  [9] include(::String) at /opt/julia/packages/CUDAnative/e0IdN/src/CUDAnative.jl:1
#  [10] top-level scope at /opt/julia/packages/CUDAnative/e0IdN/src/CUDAnative.jl:75
#  [11] include(::Function, ::Module, ::String) at ./Base.jl:380
#  [12] include(::Module, ::String) at ./Base.jl:368
#  [13] top-level scope at none:2
#  [14] eval at ./boot.jl:331 [inlined]
#  [15] eval(::Expr) at ./client.jl:467
#  [16] top-level scope at ./none:3
# in expression starting at /opt/julia/packages/CUDAnative/e0IdN/src/device/cuda/wmma.jl:52
# in expression starting at /opt/julia/packages/CUDAnative/e0IdN/src/device/cuda.jl:14
# in expression starting at /opt/julia/packages/CUDAnative/e0IdN/src/CUDAnative.jl:75
# ERROR: LoadError: Failed to precompile CUDAnative [be33ccc6-a3ff-5ff2-a52e-74243cff1e17] to /opt/julia/compiled/v1.5/CUDAnative/4Zu2W_poVfv.ji.
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] compilecache(::Base.PkgId, ::String) at ./loading.jl:1305
#  [3] _require(::Base.PkgId) at ./loading.jl:1030
#  [4] require(::Base.PkgId) at ./loading.jl:928
#  [5] require(::Module, ::Symbol) at ./loading.jl:923
#  [6] include(::Function, ::Module, ::String) at ./Base.jl:380
#  [7] include(::Module, ::String) at ./Base.jl:368
#  [8] top-level scope at none:2
#  [9] eval at ./boot.jl:331 [inlined]
#  [10] eval(::Expr) at ./client.jl:467
#  [11] top-level scope at ./none:3
# in expression starting at /opt/julia/packages/CuArrays/l0gXB/src/CuArrays.jl:3
# ERROR: LoadError: Failed to precompile CuArrays [3a865a2d-5b23-5a0f-bc46-62713ec82fae] to /opt/julia/compiled/v1.5/CuArrays/7YFE0_poVfv.ji.
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] compilecache(::Base.PkgId, ::String) at ./loading.jl:1305
#  [3] _require(::Base.PkgId) at ./loading.jl:1030
#  [4] require(::Base.PkgId) at ./loading.jl:928
#  [5] require(::Module, ::Symbol) at ./loading.jl:923
#  [6] include(::Function, ::Module, ::String) at ./Base.jl:380
#  [7] include(::Module, ::String) at ./Base.jl:368
#  [8] top-level scope at none:2
#  [9] eval at ./boot.jl:331 [inlined]
#  [10] eval(::Expr) at ./client.jl:467
#  [11] top-level scope at ./none:3
# in expression starting at /opt/julia/packages/Flux/Fj3bt/src/Flux.jl:26
# ┌ Info: Precompiling BlackBoxOptim [a134a8b2-14d6-55f6-9291-3336d3ab0209]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling LinearMaps [7a12625a-238d-50fd-b39a-03d52299707e]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling JuMP [4076af6c-e467-56ae-b986-b466b2749572]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Query [1a8c2f83-1ff3-5112-b086-8aa67b057ba1]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling DiffEqOperators [9fdde737-9c7f-55bf-ade8-46b3f136cc48]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Ipopt [b6b21f68-93f8-5de0-b562-5493be1d77c9]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling NLopt [76087f3c-5699-56af-9a33-bf431cd00edd]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling PkgTemplates [14b8a8f1-9102-5b29-a752-f990bacb7fe1]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling RDatasets [ce6b1742-4840-55fa-b093-852dadbb1d8b]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling QuantEcon [fcd29c91-0bd7-5a09-975d-7ac3f643a60c]
# └ @ Base loading.jl:1278

# %%
using Pkg
Pkg.add("PyPlot")
Pkg.add("UnicodePlots")
# Out:
#   [684fba80] ↑ SparsityDetection v0.3.1 ⇒ v0.3.3
#   [90137ffa] ↑ StaticArrays v0.12.3 ⇒ v0.12.5
#   [2913bbd2] ↑ StatsBase v0.32.2 ⇒ v0.33.2
#   [3eaba693] ↑ StatsModels v0.6.11 ⇒ v0.6.19
#   [f3b207a7] ↑ StatsPlots v0.14.6 ⇒ v0.14.17
#   [789caeaf] ↑ StochasticDiffEq v6.20.0 ⇒ v6.25.0
#   [112f6efa] ↓ VegaLite v2.1.3 ⇒ v2.0.1
#   [e88e6eb3] ↑ Zygote v0.4.20 ⇒ v0.6.2
# Updating `~/github-anari/setup-all_in_vs_code/Manifest.toml`
#   [ae81ac8f] + ASL_jll v0.1.1+4
#   [c3fe647b] + AbstractAlgebra v0.11.2
#   [79e6a3ab] ↑ Adapt v1.1.0 ⇒ v2.4.0
#   [2169fc97] ↑ AlgebraicMultigrid v0.2.2 ⇒ v0.3.0
#   [28f2ccd6] ↑ ApproxFun v0.11.13 ⇒ v0.12.3
#   [fbd15aa5] ↑ ApproxFunBase v0.3.5 ⇒ v0.3.12
#   [59844689] ↑ ApproxFunFourier v0.2.4 ⇒ v0.2.7
#   [b70543e2] ↑ ApproxFunOrthogonalPolynomials v0.3.4 ⇒ v0.3.9
#   [f8fcb915] ↑ ApproxFunSingularities v0.1.8 ⇒ v0.2.1
#   [ec485272] ↑ ArnoldiMethod v0.0.4 ⇒ v0.1.0
#   [4fba245c] ↑ ArrayInterface v2.8.7 ⇒ v2.14.17
#   [4c555306] ↑ ArrayLayouts v0.2.6 ⇒ v0.3.8
#   [56f22d72] + Artifacts v1.3.0
#   [ab4f0b2a] + BFloat16s v0.1.0
#   [aae01518] ↑ BandedMatrices v0.15.7 ⇒ v0.15.15
#   [8e7c35d0] ↑ BlockArrays v0.12.5 ⇒ v0.12.11
#   [ffab5731] ↑ BlockBandedMatrices v0.8.4 ⇒ v0.8.11
#   [6e34b625] ↑ Bzip2_jll v1.0.6+2 ⇒ v1.0.6+5
#   [fa961155] ↑ CEnum v0.3.0 ⇒ v0.4.1
#   [336ed68f] ↑ CSV v0.6.2 ⇒ v0.8.3
#   [052768ef] + CUDA v2.4.1
#   [3895d2a7] - CUDAapi v4.0.0
#   [c5f51814] - CUDAdrv v6.3.0
#   [be33ccc6] - CUDAnative v3.1.0
#   [83423d85] + Cairo_jll v1.16.0+6
#   [a603d957] ↑ CanonicalTraits v0.2.1 ⇒ v0.2.3
#   [7057c7e9] ↑ Cassette v0.3.3 ⇒ v0.3.4
#   [324d7699] ↑ CategoricalArrays v0.8.0 ⇒ v0.9.0
#   [082447d4] + ChainRules v0.7.49
#   [d360d2e6] ↑ ChainRulesCore v0.8.0 ⇒ v0.9.27
#   [aaaa29a8] ↑ Clustering v0.14.0 ⇒ v0.14.2
#   [da1fd8a2] ↑ CodeTracking v0.5.11 ⇒ v1.0.5
#   [35d6a980] ↑ ColorSchemes v3.9.0 ⇒ v3.10.2
#   [3da002f7] ↑ ColorTypes v0.10.3 ⇒ v0.10.9
#   [5ae59095] ↑ Colors v0.12.1 ⇒ v0.12.6
#   [bbf7d656] ↑ CommonSubexpressions v0.2.0 ⇒ v0.3.0
#   [34da2185] ↑ Compat v2.2.0 ⇒ v3.25.0
#   [aa819f21] + CompatHelper v1.16.3
#   [e66e0078] ↑ CompilerSupportLibraries_jll v0.3.3+0 ⇒ v0.3.4+0
#   [8f4d0f93] + Conda v1.5.0
#   [d38c429a] ↑ Contour v0.5.3 ⇒ v0.5.7
#   [adafc99b] - CpuId v0.2.2
#   [a8cc5b0e] + Crayons v4.0.4
#   [f68482b8] - Cthulhu v1.1.1
#   [3a865a2d] - CuArrays v2.2.0
#   [717857b8] ↑ DSP v0.6.7 ⇒ v0.6.10
#   [9a962f9c] ↑ DataAPI v1.3.0 ⇒ v1.4.1
#   [a93c6f00] ↑ DataFrames v0.21.0 ⇒ v0.22.5
#   [1313f7d8] ↑ DataFramesMeta v0.5.1 ⇒ v0.6.0
#   [864edb3b] ↑ DataStructures v0.17.17 ⇒ v0.17.20
#   [39dd38d3] ↑ Dierckx v0.4.1 ⇒ v0.5.1
#   [cd4c43a9] + Dierckx_jll v0.0.1+0
#   [2b5f629d] ↑ DiffEqBase v6.36.3 ⇒ v6.44.3
#   [c894b116] ↑ DiffEqJump v6.7.6 ⇒ v6.10.0
#   [77a26b50] ↑ DiffEqNoiseProcess v3.11.0 ⇒ v5.5.1
#   [9fdde737] ↑ DiffEqOperators v4.10.0 ⇒ v4.12.0
#   [163ba53b] ↑ DiffResults v1.0.2 ⇒ v1.0.3
#   [b552c78f] ↑ DiffRules v1.0.1 ⇒ v1.0.2
#   [b4f34e82] ↑ Distances v0.8.2 ⇒ v0.10.2
#   [31c24e10] ↑ Distributions v0.23.2 ⇒ v0.23.8
#   [ffbed154] ↑ DocStringExtensions v0.8.1 ⇒ v0.8.3
#   [5b8099bc] ↑ DomainSets v0.3.1 ⇒ v0.4.2
#   [fa6b7ba4] ↑ DualNumbers v0.6.2 ⇒ v0.6.3
#   [5ae413db] + EarCut_jll v2.1.5+1
#   [da5c29d0] ↑ EllipsisNotation v0.4.0 ⇒ v1.0.0
#   [2e619515] + Expat_jll v2.2.7+6
#   [2fe49d83] ↑ Expectations v1.1.1 ⇒ v1.7.1
#   [d4d017d3] ↑ ExponentialUtilities v1.6.0 ⇒ v1.8.0
#   [e2ba6199] ↑ ExprTools v0.1.1 ⇒ v0.1.3
#   [c87230d0] ↑ FFMPEG v0.3.0 ⇒ v0.4.0
#   [b22a6f82] ↑ FFMPEG_jll v4.1.0+3 ⇒ v4.3.1+4
#   [7a1cc6ca] ↑ FFTW v1.2.2 ⇒ v1.3.0
#   [f5851436] ↑ FFTW_jll v3.3.9+5 ⇒ v3.3.9+7
#   [442a2c76] ↑ FastGaussQuadrature v0.4.2 ⇒ v0.4.5
#   [057dd010] ↑ FastTransforms v0.8.2 ⇒ v0.10.3
#   [34b6f7d7] ↑ FastTransforms_jll v0.2.13+1 ⇒ v0.3.3+0
#   [5789e2e9] ↑ FileIO v1.3.0 ⇒ v1.4.5
#   [8fc22ac5] ↑ FilePaths v0.8.0 ⇒ v0.8.1
#   [48062228] ↑ FilePathsBase v0.6.2 ⇒ v0.9.8
#   [1a297f60] ↑ FillArrays v0.8.9 ⇒ v0.8.14
#   [6a86dc24] ↑ FiniteDiff v2.3.2 ⇒ v2.8.0
#   [9d5cd8c9] ↑ FixedEffectModels v0.10.7 ⇒ v1.4.0
#   [c8885935] ↑ FixedEffects v0.7.3 ⇒ v2.0.0
#   [53c48c17] ↑ FixedPointNumbers v0.8.0 ⇒ v0.8.4
#   [587475ba] ↑ Flux v0.10.4 ⇒ v0.11.6
#   [a3f928ae] + Fontconfig_jll v2.13.1+14
#   [59287772] ↑ Formatting v0.4.1 ⇒ v0.4.2
#   [f6369f11] ↑ ForwardDiff v0.10.10 ⇒ v0.10.15
#   [d7e528f0] ↑ FreeType2_jll v2.10.1+2 ⇒ v2.10.1+5
#   [559328eb] ↑ FriBidi_jll v1.0.5+3 ⇒ v1.0.5+6
#   [d9f16b24] + Functors v0.1.0
#   [0656b61e] + GLFW_jll v3.3.2+1
#   [38e38edf] ↑ GLM v1.3.9 ⇒ v1.3.11
#   [781609d7] ↑ GMP_jll v6.1.2+5 ⇒ v6.1.2+6
#   [0c68f7d7] ↑ GPUArrays v3.4.1 ⇒ v6.2.0
#   [61eb1bfa] ↑ GPUCompiler v0.2.0 ⇒ v0.8.3
#   [28b8d3ca] ↑ GR v0.49.1 ⇒ v0.53.0
#   [d2c73de3] + GR_jll v0.53.0+0
#   [6b9d7cbe] ↑ GeneralizedGenerated v0.2.4 ⇒ v0.2.8
#   [5c1252a2] + GeometryBasics v0.3.8
#   [4d00f742] - GeometryTypes v0.8.3
#   [78b55507] + Gettext_jll v0.20.1+7
#   [bc5e4493] + GitHub v5.4.0
#   [7746bdde] + Glib_jll v2.59.0+4
#   [c27321d9] + Glob v1.3.0
#   [42e2da0e] + Grisu v1.0.0
#   [cd3eb016] ↑ HTTP v0.8.15 ⇒ v0.8.19
#   [0e44f5e4] + Hwloc v1.2.0
#   [e33a78d0] + Hwloc_jll v2.4.0+0
#   [7869d1d1] ↑ IRTools v0.3.3 ⇒ v0.4.2
#   [615f187c] + IfElse v0.1.0
#   [40713840] ↑ IncompleteLU v0.1.1 ⇒ v0.2.0
#   [4858937d] ↑ InfiniteArrays v0.7.0 ⇒ v0.7.3
#   [43edad99] ↑ InstantiateFromURL v0.5.0 ⇒ v0.6.0
#   [1d5cc7b8] ↑ IntelOpenMP_jll v2018.0.3+0 ⇒ v2018.0.3+2
#   [a98d9a8b] ↑ Interpolations v0.12.9 ⇒ v0.13.1
#   [8197267c] ↑ IntervalSets v0.5.1 ⇒ v0.5.2
#   [d8418881] ↑ Intervals v1.2.0 ⇒ v1.5.0
#   [b6b21f68] ↑ Ipopt v0.6.1 ⇒ v0.6.5
#   [9cc047cb] + Ipopt_jll v3.13.2+1
#   [42fd0dbc] ↑ IterativeSolvers v0.8.4 ⇒ v0.8.5
#   [692b3bcd] + JLLWrappers v1.2.0
#   [682c06a0] ↑ JSON v0.21.0 ⇒ v0.21.1
#   [aacddb02] + JpegTurbo_jll v2.0.1+3
#   [4076af6c] ↑ JuMP v0.21.2 ⇒ v0.21.3
#   [aa1ae85d] ↑ JuliaInterpreter v0.7.19 ⇒ v0.8.8
#   [b14d175d] ↑ JuliaVariables v0.2.0 ⇒ v0.2.3
#   [e5e0dc1b] ↑ Juno v0.8.2 ⇒ v0.8.4
#   [5ab0869b] ↑ KernelDensity v0.5.1 ⇒ v0.6.2
#   [ba0b0d4f] ↑ Krylov v0.5.1 ⇒ v0.6.0
#   [0b1a1467] ↑ KrylovKit v0.4.2 ⇒ v0.5.2
#   [c1c5ebd0] ↑ LAME_jll v3.100.0+1 ⇒ v3.100.0+3
#   [929cbde3] ↑ LLVM v1.5.1 ⇒ v3.6.0
#   [dd4b983a] + LZO_jll v2.10.0+3
#   [b964fa9f] ↑ LaTeXStrings v1.1.0 ⇒ v1.2.0
#   [2ee39098] ↑ LabelledArrays v1.2.1 ⇒ v1.5.0
#   [23fbe1c1] ↑ Latexify v0.13.2 ⇒ v0.14.7
#   [5078a376] ↑ LazyArrays v0.16.9 ⇒ v0.16.16
#   [d7e5e226] + LazyBandedMatrices v0.2.12
#   [0fc2ff8b] ↑ LeastSquaresOptim v0.7.5 ⇒ v0.8.1
#   [dd192d2f] ↑ LibVPX_jll v1.8.1+1 ⇒ v1.9.0+1
#   [e9f186c6] + Libffi_jll v3.2.1+4
#   [d4300ac3] + Libgcrypt_jll v1.8.5+4
#   [7e76a0d4] + Libglvnd_jll v1.3.0+3
#   [7add5ba3] + Libgpg_error_jll v1.36.0+3
#   [94ce4f54] ↑ Libiconv_jll v1.16.0+2 ⇒ v1.16.0+7
#   [4b2f31a3] + Libmount_jll v2.34.0+3
#   [89763e89] + Libtiff_jll v4.1.0+2
#   [38a345b3] + Libuuid_jll v2.34.0+7
#   [093fc24a] ↑ LightGraphs v1.3.3 ⇒ v1.3.5
#   [d3d80556] ↑ LineSearches v7.0.1 ⇒ v7.1.1
#   [7a12625a] ↑ LinearMaps v2.6.1 ⇒ v3.2.0
#   [5c8ed15e] ↑ LinearOperators v1.1.0 ⇒ v1.2.0
#   [e6f89c97] ↑ LoggingExtras v0.4.1 ⇒ v0.4.4
#   [bdcacae8] ↑ LoopVectorization v0.8.2 ⇒ v0.10.0
#   [898213cb] ↑ LowRankApprox v0.4.0 ⇒ v0.4.3
#   [6f1432cf] ↑ LoweredCodeUtils v0.4.5 ⇒ v1.2.7
#   [d00139f3] + METIS_jll v5.1.0+5
#   [856f044c] ↑ MKL_jll v2020.1.216+0 ⇒ v2020.2.254+0
#   [d8e11817] ↑ MLStyle v0.3.1 ⇒ v0.4.6
#   [3a97d323] ↑ MPFR_jll v4.0.2+2 ⇒ v4.1.0+1
#   [d7ed1dd3] + MUMPS_seq_jll v5.2.1+4
#   [1914dd2f] ↑ MacroTools v0.5.5 ⇒ v0.5.6
#   [a3b82374] ↑ MatrixFactorizations v0.4.0 ⇒ v0.5.2
#   [739be429] ↑ MbedTLS v1.0.2 ⇒ v1.0.3
#   [c8ffd9c3] ↑ MbedTLS_jll v2.16.0+2 ⇒ v2.16.8+1
#   [e1d29d7a] ↑ Missings v0.4.3 ⇒ v0.4.5
#   [961ee093] ↑ ModelingToolkit v3.6.4 ⇒ v3.20.1
#   [ffc61752] ↑ Mustache v1.0.3 ⇒ v1.0.10
#   [d8a4904e] ↑ MutableArithmetics v0.2.9 ⇒ v0.2.14
#   [d41bc354] ↑ NLSolversBase v7.6.1 ⇒ v7.7.1
#   [079eb43e] ↑ NLopt_jll v2.6.2+0 ⇒ v2.7.0+0
#   [2774e3e8] ↑ NLsolve v4.3.0 ⇒ v4.5.1
#   [872c559c] ↑ NNlib v0.6.6 ⇒ v0.7.12
#   [77ba4419] ↑ NaNMath v0.3.3 ⇒ v0.3.5
#   [71a1bf82] ↑ NameResolution v0.1.3 ⇒ v0.1.5
#   [b8a86587] ↑ NearestNeighbors v0.4.4 ⇒ v0.4.8
#   [510215fc] ↑ Observables v0.3.1 ⇒ v0.3.3
#   [6fe1bfb0] ↑ OffsetArrays v1.0.4 ⇒ v1.5.2
#   [e7412a2a] ↑ Ogg_jll v1.3.4+0 ⇒ v1.3.4+2
#   [656ef2d0] + OpenBLAS32_jll v0.3.9+4
#   [4536629a] ↑ OpenBLAS_jll v0.3.9+4 ⇒ v0.3.9+5
#   [458c3c95] ↑ OpenSSL_jll v1.1.1+2 ⇒ v1.1.1+6
#   [efe28fd5] ↑ OpenSpecFun_jll v0.5.3+3 ⇒ v0.5.3+4
#   [429524aa] ↑ Optim v0.20.1 ⇒ v1.2.3
#   [91d4177d] ↑ Opus_jll v1.3.1+1 ⇒ v1.3.1+3
#   [bac558e1] ↑ OrderedCollections v1.2.0 ⇒ v1.3.3
#   [1dea7af3] ↑ OrdinaryDiffEq v5.38.1 ⇒ v5.42.3
#   [2f80f16e] + PCRE_jll v8.42.0+4
#   [90014a1f] ↑ PDMats v0.9.12 ⇒ v0.10.1
#   [d96e819e] ↑ Parameters v0.12.1 ⇒ v0.12.2
#   [69de0a69] ↑ Parsers v1.0.4 ⇒ v1.0.15
#   [30392449] + Pixman_jll v0.40.0+0
#   [14b8a8f1] ↑ PkgTemplates v0.6.4 ⇒ v0.7.13
#   [995b91a9] ↑ PlotUtils v1.0.4 ⇒ v1.0.10
#   [91a5bcdd] ↑ Plots v1.2.5 ⇒ v1.10.2
#   [f27b6e38] ↑ Polynomials v1.0.6 ⇒ v1.2.0
#   [2dfb63ee] ↑ PooledArrays v0.5.3 ⇒ v1.0.0
#   [85a6dd25] ↑ PositiveFactorizations v0.2.3 ⇒ v0.2.4
#   [8162dcfd] ↑ PrettyPrint v0.1.0 ⇒ v0.2.0
#   [08abe8d2] + PrettyTables v0.11.0
#   [27ebfcd6] ↑ Primes v0.4.0 ⇒ v0.5.0
#   [33c8b6b6] ↑ ProgressLogging v0.1.2 ⇒ v0.1.4
#   [92933f4c] ↑ ProgressMeter v1.2.0 ⇒ v1.4.1
#   [438e738f] + PyCall v1.92.2
#   [d330b81b] + PyPlot v2.9.0
#   [ede63266] + Qt_jll v5.15.2+1
#   [1fd47b50] ↑ QuadGK v2.3.1 ⇒ v2.4.1
#   [1a8c2f83] ↑ Query v0.12.2 ⇒ v1.0.0
#   [2aef5ad7] ↑ QueryOperators v0.9.1 ⇒ v0.9.3
#   [df47a6cb] ↑ RData v0.7.2 ⇒ v0.7.3
#   [ce6b1742] ↑ RDatasets v0.6.8 ⇒ v0.7.3
#   [74087812] + Random123 v1.3.1
#   [fb686558] + RandomExtensions v0.4.3
#   [3cdcf5f2] ↑ RecipesBase v1.0.1 ⇒ v1.1.1
#   [01d81517] ↑ RecipesPipeline v0.1.9 ⇒ v0.2.1
#   [731186ca] ↑ RecursiveArrayTools v2.3.5 ⇒ v2.11.0
#   [f2c3362d] ↑ RecursiveFactorization v0.1.2 ⇒ v0.1.9
#   [d519eb52] ↑ RegressionTables v0.4.0 ⇒ v0.5.0
#   [ae029012] ↑ Requires v1.0.1 ⇒ v1.1.2
#   [ae5879a3] ↑ ResettableStacks v1.0.0 ⇒ v1.1.0
#   [295af30f] ↑ Revise v2.6.6 ⇒ v3.1.11
#   [f50d1b31] ↑ Rmath_jll v0.2.2+0 ⇒ v0.2.2+1
#   [f2b01f46] ↑ Roots v1.0.1 ⇒ v1.0.7
#   [21efa798] - SIMDPirates v0.8.5
#   [476501e8] ↑ SLEEFPirates v0.5.0 ⇒ v0.6.8
#   [6c6a2e73] + Scratch v1.0.3
#   [91c51154] + SentinelArrays v1.2.16
#   [992d4aef] ↑ Showoff v0.3.1 ⇒ v0.3.2
#   [699a6c99] ↑ SimpleTraits v0.9.2 ⇒ v0.9.3
#   [2133526b] + SodiumSeal v0.1.1
#   [47a9eef4] ↑ SparseDiffTools v1.8.0 ⇒ v1.13.0
#   [684fba80] ↑ SparsityDetection v0.3.1 ⇒ v0.3.3
#   [90137ffa] ↑ StaticArrays v0.12.3 ⇒ v0.12.5
#   [2913bbd2] ↑ StatsBase v0.32.2 ⇒ v0.33.2
#   [4c63d2b9] ↑ StatsFuns v0.9.5 ⇒ v0.9.6
#   [3eaba693] ↑ StatsModels v0.6.11 ⇒ v0.6.19
#   [f3b207a7] ↑ StatsPlots v0.14.6 ⇒ v0.14.17
#   [789caeaf] ↑ StochasticDiffEq v6.20.0 ⇒ v6.25.0
#   [09ab397b] + StructArrays v0.4.4
#   [856f2bd8] + StructTypes v1.2.3
#   [fd094767] ↑ Suppressor v0.1.1 ⇒ v0.2.0
#   [d1185830] ↑ SymbolicUtils v0.3.2 ⇒ v0.5.2
#   [ab02a1b2] ↑ TableOperations v0.2.1 ⇒ v0.3.0
#   [bd369af6] ↑ Tables v1.0.4 ⇒ v1.3.1
#   [5d786b92] ↑ TerminalLoggers v0.1.1 ⇒ v0.1.3
#   [8290d209] + ThreadingUtilities v0.2.3
#   [f269a46b] ↑ TimeZones v1.2.0 ⇒ v1.5.3
#   [c751599d] ↑ ToeplitzMatrices v0.6.1 ⇒ v0.6.3
#   [3a884ed6] ↑ UnPack v1.0.1 ⇒ v1.0.2
#   [1986cc42] ↑ Unitful v1.2.1 ⇒ v1.5.0
#   [ec2bfdc2] + Vcov v0.4.0
#   [3d5dd08c] ↑ VectorizationBase v0.12.6 ⇒ v0.16.2
#   [239c3e63] - Vega v0.1.1
#   [112f6efa] ↓ VegaLite v2.1.3 ⇒ v2.0.1
#   [81def892] + VersionParsing v1.2.0
#   [a2964d1f] + Wayland_jll v1.17.0+4
#   [2381bf8a] + Wayland_protocols_jll v1.18.0+4
#   [ea10d353] - WeakRefStrings v0.6.2
#   [efce3f68] ↑ WoodburyMatrices v0.5.2 ⇒ v0.5.3
#   [02c8fc9c] ↑ XML2_jll v2.9.9+4 ⇒ v2.9.10+3
#   [aed1982a] + XSLT_jll v1.1.33+4
#   [4f6342f7] + Xorg_libX11_jll v1.6.9+4
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.9+4
#   [935fb764] + Xorg_libXcursor_jll v1.2.0+4
#   [a3789734] + Xorg_libXdmcp_jll v1.1.3+4
#   [1082639a] + Xorg_libXext_jll v1.3.4+4
#   [d091e8ba] + Xorg_libXfixes_jll v5.0.3+4
#   [a51aa0fd] + Xorg_libXi_jll v1.7.10+4
#   [d1454406] + Xorg_libXinerama_jll v1.1.4+4
#   [ec84b674] + Xorg_libXrandr_jll v1.5.2+4
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.10+4
#   [14d82f49] + Xorg_libpthread_stubs_jll v0.1.0+3
#   [c7cfdc94] + Xorg_libxcb_jll v1.13.0+3
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.0+4
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.2+4
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.27.0+4
#   [c5fb5394] + Xorg_xtrans_jll v1.4.0+3
#   [a5390f91] ↑ ZipFile v0.9.2 ⇒ v0.9.3
#   [83775a58] ↑ Zlib_jll v1.2.11+10 ⇒ v1.2.11+18
#   [3161d3a3] + Zstd_jll v1.4.8+0
#   [e88e6eb3] ↑ Zygote v0.4.20 ⇒ v0.6.2
#   [700de1a5] ↑ ZygoteRules v0.2.0 ⇒ v0.2.1
#   [0ac62f75] ↑ libass_jll v0.14.0+2 ⇒ v0.14.0+4
#   [f638f0a6] ↑ libfdk_aac_jll v0.1.6+2 ⇒ v0.1.6+4
#   [b53b4c65] + libpng_jll v1.6.37+6
#   [a9144af2] + libsodium_jll v1.0.18+1
#   [f27f6e37] ↑ libvorbis_jll v1.3.6+4 ⇒ v1.3.6+6
#   [1270edf5] ↑ x264_jll v2019.5.25+2 ⇒ v2020.7.14+2
#   [dfaa095f] ↑ x265_jll v3.0.0+1 ⇒ v3.0.0+3
#   [d8fb68d0] + xkbcommon_jll v0.9.1+5
#    Building GR ────────────→ `/opt/julia/packages/GR/RlE5Y/deps/build.log`
#    Building Ipopt ─────────→ `/opt/julia/packages/Ipopt/P1XLY/deps/build.log`
#    Building FFTW ──────────→ `/opt/julia/packages/FFTW/ayqyZ/deps/build.log`
#    Building TimeZones ─────→ `/opt/julia/packages/TimeZones/K98G0/deps/build.log`
#    Building FastTransforms → `/opt/julia/packages/FastTransforms/LB2TC/deps/build.log`
#    Building PyCall ────────→ `/opt/julia/packages/PyCall/tqyST/deps/build.log`
#    Building Random123 ─────→ `/opt/julia/packages/Random123/cb3eU/deps/build.log`
#   Resolving package versions...
#   Installed UnicodePlots ─ v1.3.0
# Updating `~/github-anari/setup-all_in_vs_code/Project.toml`
#   [b8865327] + UnicodePlots v1.3.0
# Updating `~/github-anari/setup-all_in_vs_code/Manifest.toml`
#   [b8865327] + UnicodePlots v1.3.0

# %%
## Plot by using pyplot 
n = 100
x, y = range(0, 1, length = n), randn(n, 3)

using Plots; 
pyplot(size = (600, 300))

plot(
    x, y,
    line = (0.5, [4 1 0], [:path :scatter :histogram]),
    normalize = true,
    bins = 30,
    marker = (10, 0.5, [:none :+ :none]),
    markerstrokewidth = 0,
    color = [:steelblue :orangered :green],
    fill = 0.5,
    orientation = [:v :v :h],
    title = "My title",
    )
# Out:
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1278
